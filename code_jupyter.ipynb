# %%
import difflib
from docx import Document
import openai
import warnings
import re
from summarizer import Summarizer

# Configure the OpenAI GPT API key. 
openai.api_key = "OpenAI Key"

def read_docx(file_path):
    """
    Reads a DOCX file to extract all non-empty paragraphs. This function is particularly useful for processing
    documents where the content is structured in paragraphs, as it skips empty paragraphs that often do not
    contain useful information.

    ### Parameters:
    - `file_path` (str): The full path to the DOCX file, which needs to be accessible by the script.

    ### Returns:
    - list[str]: Returns a list of strings, where each string is a non-empty paragraph found in the DOCX file.
    """
    doc = Document(file_path)
    return [paragraph.text for paragraph in doc.paragraphs if paragraph.text]

def compare_documents(doc1, doc2):
    """
    Compares two lists of document strings line by line and identifies changes between them. This function uses
    the `difflib.unified_diff` to generate differences in a manner that is easy to understand and process further.

    ### Parameters:
    - `doc1` (list[str]): The text content of the first document, split into lines.
    - `doc2` (list[str]): The text content of the second document, split into lines.

    ### Returns:
    - list[str]: A list of strings where each string contains a line that has been identified as either an addition
                 (prefixed with '+') or a deletion (prefixed with '-').
    """
    doc1_text = '\n'.join(doc1)
    doc2_text = '\n'.join(doc2)
    
    diff = list(difflib.unified_diff(doc1_text.splitlines(), doc2_text.splitlines(), lineterm=''))
    return [line for line in diff if line.startswith('+') or line.startswith('-')]


def summarize_changes(changes, chunk_size=200):
    """
    Processes and summarizes document changes using GPT-3.5. Given a list of changes, this function divides
    the changes into manageable chunks and uses OpenAI's API to generate summaries for each chunk, which are then
    combined into a final comprehensive summary.

    ### Parameters:
    - `changes` (list[str]): A list containing strings of document changes.
    - `chunk_size` (int): Determines how many characters each chunk will contain for summarization, affecting
                          processing load and detail in summaries.

    ### Returns:
    - str: A single string that provides a comprehensive summary of all changes.
    """
    changes_text = ' '.join(changes)
    chunks = [changes_text[i:i + chunk_size] for i in range(0, len(changes_text), chunk_size)]
    summaries = []

    for chunk in chunks:
        summary = process_chunk(chunk)
        if summary:  # Ensure non-empty summaries
            summaries.append(summary)

    combined_summary = ' '.join(summaries)
    if len(combined_summary.split()) > 16000:
        combined_summary = second_pass_summary(combined_summary)
    return combined_summary

        
def process_chunk(chunk):
    """
    Calls the OpenAI API to summarize a chunk of text. This function handles the API interaction, sending the text
    and receiving the summarized response.

    ### Parameters:
    - `chunk` (str): A string chunk of text to be summarized.

    ### Returns:
    - str: Summarized version of the chunk, or None if there was an error during processing.
    """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "Provide a concise summary."},
                {"role": "user", "content": f"Summarize this text: {chunk}"}
            ],
            max_tokens=300
        )
        return response.choices[0].message['content']
    except Exception as e:
        print(f"Error processing chunk: {e}")
        return None    

def second_pass_summary(text):
    """
    Handles a second pass of summarization if the combined text is too long.

    ### Parameters:
    - `text` (str): Combined text from initial summarizations.

    ### Returns:
    - str: A final summarized version of the text.
    """
    chunks = [text[i:i + 16000] for i in range(0, len(text), 16000)]
    final_summaries = []
    for chunk in chunks:
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "Provide a final comprehensive summary."},
                    {"role": "user", "content": f"Provide a final summary of these changes: {chunk}"}
                ],
                max_tokens=1024
            )
            final_summaries.append(response.choices[0].message['content'])
        except Exception as e:
            print(f"Error in final summarization: {e}")
            final_summaries.append("Final summary process failed.")
    return ' '.join(final_summaries)


def format_summary_as_points(summary_text):
    """
    Formats a summary into a structured list of bullet points. This function enhances readability by organizing
    the summary into clearly defined points, making it easier to scan and comprehend.

    ### Parameters:
    - `summary_text` (str): The full text of the summary to be formatted into bullet points.

    ### Returns:
    - str: A string where each sentence of the summary is formatted as a bullet point.
    """
    sentences = re.split(r'\. |\.\n', summary_text)
    unique_sentences = set(filter(None, sentences))
    bullet_points = "\n".join(f"- {sentence.strip()}" for sentence in unique_sentences if len(sentence.strip()) > 3)
    return bullet_points


# Using BERT model for summarization

# Suppress warnings that are not crucial for the user to see, keeping the output clean and focused
warnings.filterwarnings("ignore", message="Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel")
warnings.filterwarnings("ignore", category=FutureWarning, message="The default value of `n_init` will change from 10 to 'auto' in 1.4.")

def summarize_changes_bert(changes):
    """
    Uses a BERT model to perform extractive summarization on a list of document changes.
    This function leverages a pre-trained BERT model specifically tuned for extractive summarization tasks.

    ### Parameters:
    - `changes` (list[str]): A list containing textual changes detected between two documents.

    ### Returns:
    - str: An extractive summary that captures the essence of the changes succinctly.
    """
    model = Summarizer()  # Initializes the summarization model
    changes_text = ' '.join(changes)  # Combines all changes into a single string for processing
    initial_summary = model(changes_text)  # Generates the summary based on the input text
    return initial_summary

def further_condense_summary_bert(text):
    """
    Reduces the length of an already summarized text by applying a higher compression ratio.
    This function is useful for creating even shorter summaries from detailed summaries, particularly when detail reduction is necessary.

    ### Parameters:
    - `text` (str): The text to condense further, typically already summarized.

    ### Returns:
    - str: A more concise version of the input summary, reduced by the specified ratio.
    """
    model = Summarizer()  # Reuses the BERT model for further condensation
    more_concise_summary = model(text, ratio=0.9)  # Applies a high compression ratio to significantly shorten the text
    return more_concise_summary
        
# Main execution starts here
if __name__ == "__main__":
    # Paths to the documents
    doc1_path = '/Users/soumyadasgupta/Desktop/simmons/data/Jan_2015.docx'
    doc2_path = '/Users/soumyadasgupta/Desktop/simmons/data/Mar_2023.docx'

    doc1 = read_docx(doc1_path)
    doc2 = read_docx(doc2_path)

    changes = compare_documents(doc1, doc2)
    final_summary = summarize_changes(changes)
    formatted_output_gpt = format_summary_as_points(final_summary)

    print("Structured Summary of Changes:")
    print(formatted_output_gpt)
    
    # Compare the documents to find changes using BERT
    if not changes:
        print("No changes detected between the documents.")
    else:
        # Summarize the changes using BERT
        summary = summarize_changes(changes)
        # Further condense the summary
        condensed_summary_bert = further_condense_summary_bert(summary)
        print("BERT Summary of Document Changes:")
        print(condensed_summary_bert)
# Out:
# Structured Summary of Changes:
# - Apple disclaims liability related to issues with iCloud or the Service, and users are responsible for backing up their systems and purchased content as Apple is not obligated to continue providing content through services
# - The text mentions the use of the 1-Click feature for quick transactions and outlines the process for activating in-game purchases
# - Apple has the right to cooperate with legal processes regarding user use of services and handle potential issues of harmful or infringing content
# - Apple may temporarily remove or cancel services for technical or operational reasons, making efforts to inform users of any issues and protect services from loss, corruption, attacks, viruses, or security breaches
# - Users accessing the service from outside the designated country may encounter restrictions to ensure compliance
# - Additionally, the text provides safety advice on product usage, including the Family Sharing feature and the responsibility of the organizer in managing purchases made by family members
# - Paid subscriptions for certain content are explained, including the option for automatic renewals and cancellation processes
# - Additionally, the text details the permitted usage of App Store products on different devices and the requirement for licenses in commercial and educational settings
# - The text provides a detailed overview of the Apple Family Sharing program, iTunes Store Terms and Conditions, and the iTunes Match feature
# - The text lays out the potential outcomes of breaches of agreement, including financial liabilities and legal claims
# - The text also addresses issues such as automatic updates, privacy policy, usage rules, and restrictions on commercial use of the service
# - The text also delves into the functionality and implications of features such as Ask to Buy, accessing and downloading iTunes content, and utilizing iTunes Match for music libraries
# - The comprehensive summary of the changes in the agreement with Apple includes various key points:
#
# 1
# - It also discusses fraud prevention measures and the handling of payment information
# - Overall, the text aims to ensure that users understand their rights and responsibilities when using iTunes services and provides clarity on various aspects related to account management, content usage, and subscription services
# - The text details user rights and restrictions, including the use of iTunes Plus products, syncing capabilities, rental guidelines, and limitations on burning or exporting content
# - Users can seek refunds or replacements for defective products at Apple's discretion
# - The text warns against copying, reverse-engineering, modifying, or creating derivative works without permission
# - Users are advised on their rights and responsibilities, consequences of noncompliance, and iTunes' disclaimers regarding service interruptions and liability for loss or damages
# - Users are advised on the handling of personal information and how to opt out of certain features for privacy concerns
# - Users are responsible for any claims resulting from breaching the agreement, and Apple is not responsible for data charges related to service use, with statutory exceptions for public institutions
# - Apple reserves the right to notify users of changes to the agreement and may contact users via email or push notifications for service-related information
# - It emphasizes the need to monitor usage for any adverse effects and provides guidelines for sharing content and information within Family groups
# - Users may not be able to authorize more computers to access purchased content, and Apple provides disclaimers of warranties and limits its liability, not guaranteeing uninterrupted service use
# - Additionally, it highlights the intellectual property rights and copyright regulations users must abide by, the limitations imposed on the usage and reproduction of content from the iTunes store, and the conditions under which users can submit materials or reviews
# - The text outlines a vast array of terms and conditions governing the agreement between users and iTunes for the use of various services such as the App Store, Mac App Store, and iBooks Store
# - Ultimately, users are advised to read and understand these terms before engaging with Apple's services to ensure compliance and a seamless experience
# - It addresses legal implications for copyright infringement, unauthorized reproduction, and breach of agreement terms
# - It specifies the consequences of breaching the agreement, liability disclaimers, and the right of iTunes to make changes to the agreement at any time
# - iTunes retains the right to modify or discontinue its service, terminate user accounts, and take action against violations or breaches of the agreement
# - It provides detailed guidelines on digital content management, DRM protections, burning content to disc, and back-up recommendations
# - The provided text outlines the terms and conditions agreement set by iTunes, covering various aspects of using their online stores including restrictions, intellectual property rights, trademarks, and copyrights
# - It outlines rules regarding the purchase, download, and access of digital content from the stores, as well as the association of devices with accounts
# - It emphasizes the importance of managing account security and highlights the responsibility of users, particularly in cases of unauthorized account usage
# - Overall, users must carefully review and adhere to the terms and conditions outlined in end user license agreements and usage rules to ensure legal and proper use of licensed applications and external services on Apple devices
# - The text outlines the terms and conditions for various Apple services such as the iTunes Store, Mac App Store, App Store, and iBooks Store
# - It also addresses the collection of technical data by the licensor for software updates and compatibility assurance
# - The summary covers a wide range of guidelines and terms and conditions set by Apple for its services, including subscriptions, Family Sharing, App Store purchases, and the usage of iTunes stores
# - Apple reserves the right to terminate the Agreement and/or your Apple ID without notice, holding you responsible for outstanding payments and potentially revoking software licenses and restricting access to services upon termination
# - Additional terms and conditions may apply to transactions, third-party content, or services with Apple, and users must comply with all local regulations
# - Overall, users should be aware of the terms, conditions, and responsibilities outlined in the agreement with Apple to ensure compliance and understanding of the rights and liabilities associated with using Apple services.
# - Legal matters are governed by specific laws and jurisdictions based on user location or agreement terms, with disputes resolved in designated regions or countries as outlined in the agreement
# - It explains the limitations and policies regarding gift cards, including their use and transfer
# - The changes discussed in the text cover a wide range of topics related to End User License Agreements and the use of various Apple products and services
# - Additionally, the text covers aspects related to third-party materials, trademarks, intellectual property rights, and user responsibilities when submitting content to the service
# - Users are advised to manage their billing settings and payment methods carefully
# - The agreement discusses the importance of maintaining account security and confidentiality, with users being responsible for all activities conducted on their account
# - The text underscores the significance of reviewing agreements, adhering to age restrictions, and ensuring compliance with Apple's policies when using their services
# - Users are advised to comply with applicable laws when accessing external services, as the licensor may modify or restrict access based on legal obligations
# - It addresses privacy policies, data collection practices, and personalized recommendations provided to users based on their interactions with the App Store
# - The text also explains the licensing terms for Mac App Store and App Store products, In-App Purchases, and Subscriptions
# - Users are advised on the handling of objectionable content, intellectual property rights, and the consequences of misuse of the service, including potential account termination
# - It emphasizes the importance of adhering to end user license agreements, usage rules, and restrictions set by the licensor
# - The summary also touches on the rules regarding Family Sharing, In-App Purchases, and restrictions on accessing Apple's stores using modified software or unauthorized means
# - Apple and its related entities are not liable for loss or damage unless certain conditions are not met, and Apple retains liability for fraud, gross negligence, willful misconduct, or personal injury
# - By agreeing to the terms, users can access these services, but they should not proceed if they disagree
# - It also mentions the rights and responsibilities of users in relation to copyrights and intellectual property, emphasizing the protection of Apple's trademarks and content
# - Apple has the right to change or terminate its services without notice and will not be held liable to users or third parties as a result, but may provide advance warning in case of modifications, suspensions, or discontinuations
# - Restrictions apply to the redownloading or streaming of content that becomes unavailable, except for specific circumstances outlined in the agreement or when seeking a refund or compensation under statutory rights
# - The text covers a wide range of information related to licensing agreements, use of licensed applications, and accessing external services through Apple devices
# - The agreement between a company or government institution and an individual is subject to local, national, state, or federal laws, with clauses interpreted to align with relevant governing law
# - Additionally, the text mentions limitations of liability for the licensor, as well as the need for users to back up their systems and applications
# - Users are granted nontransferable licenses for applications and are required to follow specific guidelines, such as not distributing applications over networks, transferring licenses, or engaging in unauthorized activities
# - It also highlights the consequences of security breaches, noncompliance with terms, and unauthorized use of proprietary information or materials
# - The agreement was last updated on September 12, 2022
# - Furthermore, the text outlines iTunes' disclaimers regarding service interruptions, system backups, and liability for loss or damages
# - Additionally, it covers aspects related to subscription renewal, data usage, and potential risks associated with utilizing Apple services
# - It highlights that iTunes does not guarantee uninterrupted service or error-free use and disclaims responsibility for security breaches, with users encouraged to back up their systems
# - The changes outlined in the provided text primarily focus on the usage, terms, and conditions related to iTunes products and services
# - It emphasizes the importance of adhering to the terms outlined for using Apple's services and products, including restrictions on behavior such as engaging in illegal or harmful activities, posting offensive content, or unauthorized sharing of purchased content
# - Users are advised to download purchased content to ensure continued access as it may be removed at a later time
# - Users are given options to control the sharing of their information, such as disabling the Genius feature, which collects and uses data from iTunes libraries
# - It also delves into the terms and conditions for using products from the iBooks Store and outlines the relationship between users, Apple, and third-party content providers
# - It outlines the monitoring capabilities of Mac App Store products for individual and organizational use
# - Overall, the comprehensive summary captures the key changes related to licensing agreements, product usage, and legal requirements for users engaging with Apple's services and products
# - It details payment responsibilities, taxes, and refund policies for purchases made
# - Users are required to accept any changes made to the agreement, which governs their use of the service
# - In summary, the changes detailed in the text underscore the importance of compliance with usage rules, copyright laws, and security measures when using iTunes products and services
# - The agreement serves as the complete understanding between the parties involved and requires compliance with all applicable laws and regulations
# - Apple may disclose data to law enforcement agencies or third parties as necessary to enforce compliance with the agreement, and users grant Apple the right to take steps for the service
# - Users are informed about the limitations and permissions associated with purchases and downloads within the Apple ecosystem, including the necessity of maintaining accurate registration data
# - It emphasizes the importance of adhering to usage rules, copyright laws, and security measures to prevent copyright infringement and ensure responsible use of iTunes products
# - The text explains the process for cancelling orders, and the obligations of the account holder in ensuring timely payments
# - These changes include significant points such as the limitations of liability in the agreement, consequences of breaching the agreement, restrictions on exporting Licensed Applications, rules and regulations governing commercial software licensing, and the application of various laws to user agreements
# - Specifically, the text details the consequences of violating the agreement, restrictions on exporting Licensed Applications to certain countries, and the governing laws for user agreements and product licensing
# - Additionally, the text discusses features such as iCloud Music Library, Apple Fitness+, and Carrier Memberships, providing guidelines and restrictions for using these services
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BERT Summary of Document Changes:
# This text provides a detailed overview of the terms and conditions for using Apple's digital platforms, including the iTunes Store, Mac App Store, App Store, and iBooks Store. It outlines the legal agreements users enter into by accepting the terms and conditions, covering aspects such as payment obligations, refunds, cancellations, and billing processes. The text highlights the importance of reading the agreement carefully and emphasizes the user's responsibility to comply with the terms outlined. It also delves into specific features such as Family Sharing, 1-Click purchasing, and the provision of services and content on Apple platforms. Users are advised on safety measures when using digital products, including taking breaks to avoid strain and potential health risks. The text also outlines procedures for managing payments, cancellations, and refunds, providing users with clear guidance on their rights and responsibilities when interacting with Apple's digital services. The text highlights changes and rules related to Family Sharing, Ask to Buy feature, iTunes content access, iTunes Match, and Genius feature usage. It also covers details regarding iTunes products access, download limits, and device associations. Additionally, it explains the terms and conditions of iTunes Store service, including account security, content purchasing, and limitations on content sharing and downloading. The text provides information on iTunes Match subscription service, emphasizing data security and responsibility for data backup. It discusses the association of devices with iTunes Match, restrictions on simultaneous device usage, and the collection of media information for music recommendations. It also outlines the process for opting in and out of the Genius feature, the use of personalized data for recommendations, and the importance of maintaining data privacy and security. Overall, the text serves as a comprehensive guide for users on managing their accounts, accessing content, and understanding the terms and conditions associated with using iTunes services and features. The text discusses the comprehensive terms and conditions of using iTunes products and services, emphasizing the importance of compliance with security regulations and copyright laws set by iTunes and its licensors. Users are guided on the security framework, usage rules, and limitations regarding the acquisition, storage, and usage of iTunes products like music, films, and TV episodes. Various guidelines are outlined for accessing and syncing content across devices, including film rentals and film transfers. Users are advised on content viewing timeframes, backups, and the importance of managing their purchased content effectively. The text underscores the role of iTunes in maintaining and securing the service while prohibiting security breaches and violations such as reverse-engineering. Users are informed about payment terms, refunds, and content access regulations, especially in cases of Season Passes and Multi-Pass subscriptions. iTunes maintains its rights to enforce the agreement, terminate accounts, and modify the service as needed. It clarifies the binding nature of the agreement, the potential changes that could occur, and specifies the applicable laws governing the service's usage. Overall, the text provides a thorough overview of the rights and responsibilities of users when engaging with iTunes products and services, aiming to protect intellectual property, enhance security, and maintain a fair and lawful digital ecosystem. The provided text encompasses a wide array of information regarding the terms and conditions governing the use of iTunes services, including the App Store, Mac App Store, iBooks Store, and related products. The document touches upon various aspects such as the right of iTunes to disclose user information to enforce compliance, the registration and creation of user accounts, guidelines for access and use of services, content downloading an ...
